# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bh= pd.read_csv('C:/Users/kgpr/OneDrive/Desktop/New folder/bostonhousing.csv')

# %%
bh1=pd.DataFrame(data=bh)

# %%
bh1.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
bh1.tail()
# Out:
#       ID     crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 328  500  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9

# %%
bh1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
# ID         333 non-null int64
# crim       333 non-null float64
# zn         333 non-null float64
# indus      333 non-null float64
# chas       333 non-null int64
# nox        333 non-null float64
# rm         333 non-null float64
# age        333 non-null float64
# dis        333 non-null float64
# rad        333 non-null int64
# tax        333 non-null int64
# ptratio    333 non-null float64
# black      333 non-null float64
# lstat      333 non-null float64
# medv       333 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
bh1.describe().T
# Out:
#          count        mean         std        min        25%        50%  \
# ID       333.0  250.951952  147.859438    1.00000  123.00000  244.00000
# crim     333.0    3.360341    7.352272    0.00632    0.07896    0.26169
# zn       333.0   10.689189   22.674762    0.00000    0.00000    0.00000
# indus    333.0   11.293483    6.998123    0.74000    5.13000    9.90000
# chas     333.0    0.060060    0.237956    0.00000    0.00000    0.00000
# nox      333.0    0.557144    0.114955    0.38500    0.45300    0.53800
# rm       333.0    6.265619    0.703952    3.56100    5.88400    6.20200
# age      333.0   68.226426   28.133344    6.00000   45.40000   76.70000
# dis      333.0    3.709934    1.981123    1.12960    2.12240    3.09230
# rad      333.0    9.633634    8.742174    1.00000    4.00000    5.00000
# tax      333.0  409.279279  170.841988  188.00000  279.00000  330.00000
# ptratio  333.0   18.448048    2.151821   12.60000   17.40000   19.00000
# ...

# %%
print(bh1.shape)
# Out:
# (333, 15)

# %%
print(bh1.columns)
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
bh1.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
bh1.dtypes
# Out:
# ID           int64
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
bh1.corr('pearson')
# Out:
#                ID      crim        zn     indus      chas       nox        rm  \
# ID       1.000000  0.456312 -0.155639  0.421978  0.007958  0.440185 -0.112790
# crim     0.456312  1.000000 -0.210913  0.422228 -0.041195  0.463001 -0.310180
# zn      -0.155639 -0.210913  1.000000 -0.518679 -0.024442 -0.501990  0.328197
# indus    0.421978  0.422228 -0.518679  1.000000  0.037496  0.750087 -0.440365
# chas     0.007958 -0.041195 -0.024442  0.037496  1.000000  0.080275  0.112251
# nox      0.440185  0.463001 -0.501990  0.750087  0.080275  1.000000 -0.338515
# rm      -0.112790 -0.310180  0.328197 -0.440365  0.112251 -0.338515  1.000000
# age      0.257300  0.379034 -0.544513  0.638378  0.068286  0.736000 -0.248573
# dis     -0.356461 -0.397067  0.637142 -0.702327 -0.081834 -0.769364  0.269191
# rad      0.707526  0.666636 -0.303663  0.569779  0.007714  0.612180 -0.272783
# tax      0.686246  0.617081 -0.311180  0.708313 -0.021826  0.670722 -0.356987
# ...

# %%
plt.figure(figsize=(9,5))
sns.heatmap(bh1.corr('pearson'),cmap='coolwarm', annot=True, linewidth=.5)

# %%
sns.set_style("darkgrid")
sns.boxplot(data=bh1);
plt.title("darkgrid")
# Out:
# Text(0.5, 1.0, 'darkgrid')

# %%
sns.pairplot(bh1, kind="scatter", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %%
new_bh1 = bh1[['rm','zn','chas','dis','black','lstat','medv']]

# %%
new_bh1.describe().T
# Out:
#        count        mean        std     min       25%       50%       75%  \
# rm     333.0    6.265619   0.703952  3.5610    5.8840    6.2020    6.5950
# zn     333.0   10.689189  22.674762  0.0000    0.0000    0.0000   12.5000
# chas   333.0    0.060060   0.237956  0.0000    0.0000    0.0000    0.0000
# dis    333.0    3.709934   1.981123  1.1296    2.1224    3.0923    5.1167
# black  333.0  359.466096  86.584567  3.5000  376.7300  392.0500  396.2400
# lstat  333.0   12.515435   7.067781  1.7300    7.1800   10.9700   16.4200
# medv   333.0   22.768769   9.173468  5.0000   17.4000   21.6000   25.0000
#
#             max
# rm       8.7250
# zn     100.0000
# chas     1.0000
# dis     10.7103
# black  396.9000
# lstat   37.9700
# medv    50.0000

# %%
sns.set_style("darkgrid")
sns.boxplot(data=new_bh1);
plt.title("darkgrid")
# Out:
# Text(0.5, 1.0, 'darkgrid')

# %%
plt.figure(figsize=(9,5))
sns.heatmap(new_bh1.corr('pearson'),cmap='coolwarm', annot=True, linewidth=.5)

# %%
sns.pairplot(new_bh1, kind="scatter", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scaled_data = scale.fit_transform(bh1)
scaled_data
# Out:
# C:\Users\kgpr\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\kgpr\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[-1.69301403, -0.45687496,  0.32290583, ...,  0.43298984,
#         -1.06777158,  0.13441853],
#        [-1.68624067, -0.45401577, -0.47212294, ...,  0.43298984,
#         -0.47829937, -0.12759925],
#        [-1.67269396, -0.45332651, -0.47212294, ...,  0.40673324,
#         -1.35683968,  1.16065484],
#        ...,
#        [ 1.70721164, -0.45156931, -0.47212294, ...,  0.43298984,
#         -0.48680137, -0.23677333],
#        [ 1.713985  , -0.4494593 , -0.47212294, ...,  0.43298984,
#         -0.97424954,  0.12350112],
# ...

# %%
scaled_bh= pd.DataFrame(scaled_data,columns=bh1.columns)
scaled_bh.head()
# Out:
#          ID      crim        zn     indus     chas       nox        rm  \
# 0 -1.693014 -0.456875  0.322906 -1.285631 -0.25278 -0.166787  0.440154
# 1 -1.686241 -0.454016 -0.472123 -0.604425 -0.25278 -0.767928  0.221060
# 2 -1.672694 -0.453327 -0.472123 -1.304235 -0.25278 -0.863762  1.041952
# 3 -1.665921 -0.448330 -0.472123 -1.304235 -0.25278 -0.863762  1.253933
# 4 -1.652374 -0.445709  0.079980 -0.489936 -0.25278 -0.288758 -0.360821
#
#         age       dis      rad       tax   ptratio     black     lstat  \
# 0 -0.107736  0.192133 -0.98907 -0.664062 -1.465171  0.432990 -1.067772
# 1  0.379963  0.635528 -0.87451 -0.980620 -0.301616  0.432990 -0.478299
# 2 -0.798347  1.189127 -0.75995 -1.097863  0.117264  0.406733 -1.356840
# 3 -0.499320  1.189127 -0.75995 -1.097863  0.117264  0.432990 -1.018177
# 4 -0.057898  0.935505 -0.53083 -0.576130 -1.511713  0.417953 -0.012106
#
#        medv
# 0  0.134419
# 1 -0.127599
# 2  1.160655
# 3  1.466342
# 4  0.014327

# %%
scaled_bh.corr()
# Out:
#                ID      crim        zn     indus      chas       nox        rm  \
# ID       1.000000  0.456312 -0.155639  0.421978  0.007958  0.440185 -0.112790
# crim     0.456312  1.000000 -0.210913  0.422228 -0.041195  0.463001 -0.310180
# zn      -0.155639 -0.210913  1.000000 -0.518679 -0.024442 -0.501990  0.328197
# indus    0.421978  0.422228 -0.518679  1.000000  0.037496  0.750087 -0.440365
# chas     0.007958 -0.041195 -0.024442  0.037496  1.000000  0.080275  0.112251
# nox      0.440185  0.463001 -0.501990  0.750087  0.080275  1.000000 -0.338515
# rm      -0.112790 -0.310180  0.328197 -0.440365  0.112251 -0.338515  1.000000
# age      0.257300  0.379034 -0.544513  0.638378  0.068286  0.736000 -0.248573
# dis     -0.356461 -0.397067  0.637142 -0.702327 -0.081834 -0.769364  0.269191
# rad      0.707526  0.666636 -0.303663  0.569779  0.007714  0.612180 -0.272783
# tax      0.686246  0.617081 -0.311180  0.708313 -0.021826  0.670722 -0.356987
# ...

# %%
sns.lmplot(x='lstat', y='medv', data=new_bh1)

# %%
sns.lmplot(x='rm', y='medv', data=new_bh1)

# %%
sns.lmplot(x='zn', y='medv', data=new_bh1)

# %%
sns.lmplot(x='chas', y='medv', data=new_bh1)

# %%
sns.lmplot(x='dis', y='medv', data=new_bh1)

# %%
sns.lmplot(x='black', y='medv', data=new_bh1)

# %%
from sklearn import linear_model
import statsmodels.api as sm
X=new_bh1[['rm','zn']]
Y=new_bh1['medv']

model=sm.OLS(Y,X).fit()
predictions=model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     1702.
# Date:                Mon, 19 Aug 2019   Prob (F-statistic):          6.70e-175
# Time:                        12:11:08   Log-Likelihood:                -1134.8
# No. Observations:                 333   AIC:                             2274.
# Df Residuals:                     331   BIC:                             2281.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rm             3.5256      0.072     49.222      0.000       3.385       3.666
# ...

# %%
X=new_bh1[['rm','lstat']]
Y=new_bh1['medv']

model1=sm.OLS(Y,X).fit()
predictions=model.predict(X)

model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     3084.
# Date:                Mon, 19 Aug 2019   Prob (F-statistic):          1.03e-214
# Time:                        12:13:43   Log-Likelihood:                -1042.5
# No. Observations:                 333   AIC:                             2089.
# Df Residuals:                     331   BIC:                             2097.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rm             4.9429      0.087     56.802      0.000       4.772       5.114
# ...

# %%
X=new_bh1[['rm','dis']]
Y=new_bh1['medv']

model2=sm.OLS(Y,X).fit()
predictions=model.predict(X)

model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     1575.
# Date:                Mon, 19 Aug 2019   Prob (F-statistic):          7.92e-170
# Time:                        12:14:18   Log-Likelihood:                -1146.5
# No. Observations:                 333   AIC:                             2297.
# Df Residuals:                     331   BIC:                             2305.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rm             3.4414      0.145     23.677      0.000       3.156       3.727
# ...

# %%
X=new_bh1[['rm','black']]
Y=new_bh1['medv']

model3=sm.OLS(Y,X).fit()
predictions=model.predict(X)

model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     1579.
# Date:                Mon, 19 Aug 2019   Prob (F-statistic):          5.21e-170
# Time:                        12:14:54   Log-Likelihood:                -1146.1
# No. Observations:                 333   AIC:                             2296.
# Df Residuals:                     331   BIC:                             2304.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rm             3.1189      0.272     11.456      0.000       2.583       3.654
# ...
